# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import re

# %%
#Data Science
job_title = []
job_description1 = []
Date = []
Salary = []
job_type = []
location = []
category = []
company_name = []
for u in range(1, 124):
    url = "https://www.seek.com.au/Data-Science-jobs/in-All-Melbourne-VIC?daterange=3&page=" + str(u)
    response = requests.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'lxml')
    a = soup.find_all("a", {"class": "_2iNL7wI"})
    
#     for i, v in enumerate(soup.find_all("a", {"class": "_3AMdmRg"})):
      
#         if i == 0:
#             company_name.append(v.text)
#         elif i == 5:
#             company_name.append(v.text)
#         elif i == 10:
#             company_name.append(v.text)
#         elif i == 14:
#             company_name.append(v.text)
#         elif i == 19:
#             company_name.append(v.text)
#         elif i == 24:
#             company_name.append(v.text)
#         elif i == 29:
#             company_name.append(v.text)
#         elif i == 34:
#             company_name.append(v.text)
#         elif i == 39:
#             company_name.append(v.text)
#         elif i == 44:
#             company_name.append(v.text)
#         elif i == 49:
#             company_name.append(v.text)
#         elif i == 54:
#             company_name.append(v.text)
#         elif i == 59:
#             company_name.append(v.text)
#         elif i == 64:
#             company_name.append(v.text)
#         elif i == 69:
#             company_name.append(v.text)
#         elif i == 74:
#             company_name.append(v.text)
#         elif i == 78:
#             company_name.append(v.text)
#         elif i == 83:
#             company_name.append(v.text)
#         elif i == 87:
#             company_name.append(v.text)
#         elif i == 92:
#             company_name.append(v.text)
        
    
    l = "https://www.seek.com.au"
    job_links = []
    for link in a:
        if link.has_attr('href'):
            job_links.append(l + link.attrs['href'])
        else:
            pass
    for j in job_links:
        response1 = requests.get(j)
        soup1 = BeautifulSoup(response1.text, 'lxml')
        try:
            d = soup1.find("div", {"class" : "_2e4Pi2B"})
            job_description1.append(d.renderContents())
        except:
            job_description1.append("NA")              

          
        for k, v in enumerate(soup1.find_all("span", {"class": "lwHBT6d"})):
            if k == 0:
                job_title.append(v.text)
            elif k == 1:
                Date.append(v.text)
            elif k == 2:
                Salary.append(v.text)
            elif k == 3:
                job_type.append(v.text)
            else:
                pass 

        for l, c in enumerate(soup1.find_all("strong", {"class": "lwHBT6d"})):
            if l == 0:
                pass
            elif l == 1:
                location.append(c.text)
            elif l == 2:
                category.append(c.text)
            else:
                pass

# %%
len(job_title)
# Out:
# 126

# %%
job_title
# Out:
# ['Web Analytics Manager',
#  'Data Scientist',
#  'Junior Data Scientist',
#  'Senior Data Analyst',
#  'Web Analytics Manager',
#  'Data Scientist',
#  'Data Scientist',
#  'Business Data Consultant',
#  'Data Scientist',
#  'Data Scientist - Central Coast NSW',
#  'Data Architect - Opensource',
#  'Marketing Analytics Manager',
#  'Data Insights Analyst',
#  'Data Engineer - Perm - Melb - AWS',
#  'Senior Software Engineer - Javascript, ReactJS, D3js, Python',
#  'Ruby on Rails Engineer',
#  'Ruby on Rails Engineer',
#  'Junior Software Developer(Frontend/Scala/JAVA/Big Data)',
#  'Marketing Automation Analyst',
#  'Pre-Sales Engineer',
#  'Senior Data Analyst / Engineer | Greenfields team',
#  'Principal Engineer | Hands on lead | Predictive Analytics & AI Technology',
#  'Data Governance Program Manager',
#  'Data Governance Program Manager',
#  'Program Manager',
#  'Big Data Engineer',
#  'Senior Product Manager',
#  'Big Data Engineer',
#  'BI Analyst',
#  'Head of Analytics & Insights',
#  'Security Analyst',
#  'Warehouse Operators Pick Packers - Casuals',
#  'GP / Medical Representatives  x2 roles',
#  'App Developer - IOS and Android',
#  'Senior Research Scientist - Agriculture',
#  'Senior Quantitative Developer, Investment Solutions - 6 Month Contract',
#  'Data Scientist',
#  'IT Network and Security Engineer',
#  'Administrative Officer, Reporting',
#  'Medical Science Liaison | National - (Sydney based opportunity)',
#  'Hospital Specialist Representatives - Victoria (multiple roles)',
#  'Science Project Officer',
#  'Science Project Officer',
#  'Senior Academic Governance Officer',
#  'Senior Academic Governance Officer',
#  'Policy and Projects Coordinator',
#  'Senior Analyst - Scorecards',
#  'Credit Risk Modeling Analyst - Scorecards ',
#  'Senior Analyst',
#  'Postdoctoral Fellowship in Biostatistics',
#  'Postdoctoral Fellowship in Biostatistics',
#  'Classroom Teacher - Science',
#  'Senior Asset Information Officer',
#  'Senior Asset Information Officer',
#  'VCE Biology/Science Classroom Teacher',
#  'Co-ord Community Transport',
#  'Co-ord Community Transport',
#  'Clinical Quality and Compliance Manager Melbourne',
#  'Science Classroom Teacher',
#  'BUSINESS ANALYST',
#  'Quantitative Developer - Wealth Management',
#  'Events and Marketing Officer',
#  'Events and Marketing Officer',
#  'Senior Java Developer (CONTRACT)',
#  'Quantitative Developer - Wealth Management',
#  'Snr Python Developer - Wealth Management',
#  'Cardiac Audit Coordinator - Medical Services',
#  'SAP FICO Consultant',
#  'Scientific Programmer - Coastal Hazards',
#  'Scientific Programmer - Coastal Hazards',
#  'Spatial Information Consultant (GIS Consultant)',
#  'Security Administrator',
#  'Customer Success Manager',
#  'Database Administrator/.Net Developer',
#  'SAP FICO + RE (Real Estate) Consultant',
#  'IT System Administrator',
#  'Senior User Experience (UX) Researcher',
#  'Research Assistant',
#  'SAP consultant ',
#  'Mulesoft Architect',
#  'Home- based (Senior) Clinical Research Associate',
#  'Research Fellow: Space Physics/ Space Situational Awareness',
#  'Research Fellow: Space Physics/ Space Situational Awareness',
#  'Humanities,History and VCE politics Teacher',
#  'LIMS Administrator',
#  'Clinical Research Associate/Senior CRA- Home based',
#  'Backup Engineer',
#  'Finance - Accounts Payable',
#  'Laboratory Assistant - Northern suburbs',
#  'Senior IT Business Analyst',
#  'Ed Support Level 1-Range 2',
#  'Enrolments and Communications Officer',
#  'Bid Coordinator',
#  'RESEARCH FELLOW IN EPIDEMIOLOGY OF LUNG HEALTH',
#  'Research Officer/Senior Research Officer, Survey Methodology Team',
#  'Senior Learning Assistant',
#  'Administration / Enrolment Officer',
#  'Generalist Primary',
#  'Research Fellow, Infectious Diseases Network Analysis and Modelling',
#  'Research Fellow, Infectious Diseases Network Analysis and Modelling',
#  'Research Fellow',
#  'Research Fellow',
#  'BioPharma and VAM Key Account Manager',
#  'Literacy',
#  'New Arrivals EAL P-12 Classroom Teacher',
#  'PhD Scholarships in Electrocatalysis',
#  'PhD Scholarships in Electrocatalysis',
#  'Library Assistant (fixed term position)',
#  'Ed Support Level 1-Range 1',
#  'Admin Assistant - Accounts Receivable',
#  'Instrumental Music - Piano 0.3',
#  'Clinical Project Manager -Melbourne',
#  'Admin Assistant - Accounts',
#  'Specific Needs Program Assistant - Numeracy',
#  'Woodwork Classroom Teacher',
#  'New Product Development Manager | Meat Manufacture',
#  'Music - Performing Arts teacher',
#  'Physical Education Teacher',
#  'Commercialisation Manager - External Manufacturing',
#  'Accounts Payable / General Office Administration',
#  'Mathematics / Information Technology Classroom Teacher',
#  'Counterfeit Analyst',
#  'Counterfeit Analyst',
#  'Finance, Accounts - General Administration',
#  'Web Analytics Manager',
#  'Web Analytics Manager']

# %%
Salary
# Out:
# ['Full Time',
#  'Full Time',
#  'up to $90,000',
#  '$120,000 - $145,000',
#  'Full Time',
#  '$125000',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Contract/Temp',
#  'plus super and bonus',
#  'Competitive Salary package',
#  'Full Time',
#  'Full Time',
#  "Melb CBD, $800-$1100 per day, 6 Month + EXT's",
#  'Full Time',
#  'Full Time',
#  '$55,000 - $59,999',
#  'Full Time',
#  '$160,000',
#  '$100K - $135K',
#  'Full Time',
#  '$109,673-$116,295',
#  '$109,673-$116,295',
#  'Salary Packaging',
#  'including super',
#  'Full Time',
#  '£12000.00 - £140000.00 p.a. + plus super ',
#  'Full Time',
#  'Full Time',
#  '$90k - $100k p.a. + super',
#  '$20 - $29.99 per hour',
#  'Base + Company car + Super + Bonus',
#  'Full Time',
#  'Full Time',
#  '$800 - $1000k per day',
#  'Part Time',
#  'Full Time',
#  'Full Time',
#  'car + petrol + health insurance ',
#  'Full Time',
#  '$67,866 - $75,136 ',
#  '$67,866 - $75,136 ',
#  '$87,249 - $95,695 pa HEW Level 07 (plus 17% super)',
#  '$87,249 - $95,695 pa HEW Level 07 (plus 17% super)',
#  'Full Time',
#  '$115000.00 - $130000.00 p.a.',
#  '$115000.00 - $130000.00 p.a.',
#  'Full Time',
#  'Contract/Temp',
#  'Contract/Temp',
#  'Part Time',
#  'Full Time',
#  'Full Time',
#  'Part Time',
#  'Contract/Temp',
#  'Contract/Temp',
#  'Full Time',
#  'Part Time',
#  'Full Time',
#  '$950 pd + gst',
#  '$68,159 - $78,291 pa HEW 05 (plus 9.5% super)',
#  '$68,159 - $78,291 pa HEW 05 (plus 9.5% super)',
#  'Contract/Temp',
#  '$950 pd + gst',
#  '$950 pd + gst',
#  'Part Time',
#  '$100k - $120k p.a.',
#  '$82K - $93K + up to 15.4% super',
#  '$82K - $93K + up to 15.4% super',
#  '$35 - $45 per hour',
#  'Full Time',
#  '$65,000 - $70,000 inc super',
#  'Full Time',
#  '110,000 - 120,000 Base + Super ',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  '$120k - $130k p.a.',
#  '$100000.00 - $120000.00 per annum',
#  'Full Time',
#  '$94671 - $112425 p.a. + super',
#  '$94671 - $112425 p.a. + super',
#  'Full Time',
#  'Contract/Temp',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Contract/Temp',
#  'Contract/Temp',
#  'Part Time',
#  'Part Time',
#  'Full Time',
#  'Full Time',
#  'APS3-4 $57,596 - $69,698APS5-6 $72,070 - $88,827',
#  'Part Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  '$98,407 - $116,186 p.a.',
#  '$98,407 - $116,186 p.a.',
#  '$95,000 - $119,999',
#  'Part Time',
#  'Part Time',
#  '$27,872 pa full-time rate (tax-free stipend)',
#  '$27,872 pa full-time rate (tax-free stipend)',
#  '$60,000 - $64,999',
#  'Part Time',
#  'Part Time',
#  'Part Time',
#  'Full Time',
#  'Part Time',
#  'Part Time',
#  'Full Time',
#  'Salary $80K - $100K neg INC super!',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Part Time',
#  'Full Time',
#  'Part Time',
#  'Part Time',
#  'Full Time',
#  'Full Time',
#  'Full Time']

# %%
len(job_description1)
# Out:
# 126

# %%
len(location)
# Out:
# 126

# %%
len(Date)
# Out:
# 126

# %%
len(job_type)
# Out:
# 126

# %%
len(category)
# Out:
# 126

# %%
job_type
# Out:
# ['Share this role',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Contract/Temp',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Contract/Temp',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Casual/Vacation',
#  'Contract/Temp',
#  'Share this role',
#  'Share this role',
#  'Contract/Temp',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Contract/Temp',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Contract/Temp',
#  'Contract/Temp',
#  'Share this role',
#  'Full Time',
#  'Contract/Temp',
#  'Contract/Temp',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Contract/Temp',
#  'Contract/Temp',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Full Time',
#  'Part Time',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Full Time',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role',
#  'Share this role']

# %%
Date
# Out:
# ['13 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '15 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '14 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '13 Feb 2019',
#  '14 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '15 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '14 Feb 2019',
#  '12 Feb 2019',
#  '14 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '12 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '14 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '13 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '13 Feb 2019',
#  '14 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '12 Feb 2019',
#  '15 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '15 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '14 Feb 2019',
#  '14 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '14 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019',
#  '12 Feb 2019',
#  '13 Feb 2019',
#  '13 Feb 2019']

# %%
search_key = []
for i in range(1, 127):
    search_key.append("Data Science")

# %%
seek_data_15th = pd.DataFrame({'job_title': job_title, 'Date':Date, 'Salary': Salary, 'job_type':job_type, 'category':category, 'location':location, 'job_description': job_description1, 'search_key': search_key}, columns =['job_title', 'Date', 'Salary', 'job_type', 'category', 'location', 'job_description', 'search_key'])

# %%
seek_data_15th
# Out:
#                                              job_title         Date  \
# 0                                Web Analytics Manager  13 Feb 2019
# 1                                       Data Scientist  13 Feb 2019
# 2                                Junior Data Scientist  12 Feb 2019
# 3                                  Senior Data Analyst  12 Feb 2019
# 4                                Web Analytics Manager  13 Feb 2019
# 5                                       Data Scientist  12 Feb 2019
# 6                                       Data Scientist  13 Feb 2019
# 7                             Business Data Consultant  13 Feb 2019
# 8                                       Data Scientist  12 Feb 2019
# 9                   Data Scientist - Central Coast NSW  13 Feb 2019
# 10                         Data Architect - Opensource  12 Feb 2019
# 11                         Marketing Analytics Manager  12 Feb 2019
# 12                               Data Insights Analyst  13 Feb 2019
# 13                   Data Engineer - Perm - Melb - AWS  15 Feb 2019
# 14   Senior Software Engineer - Javascript, ReactJS...  12 Feb 2019
# 15                              Ruby on Rails Engineer  13 Feb 2019
# 16                              Ruby on Rails Engineer  13 Feb 2019
# 17   Junior Software Developer(Frontend/Scala/JAVA/...  14 Feb 2019
# 18                        Marketing Automation Analyst  12 Feb 2019
# 19                                  Pre-Sales Engineer  12 Feb 2019
# 20   Senior Data Analyst / Engineer | Greenfields team  15 Feb 2019
# 21   Principal Engineer | Hands on lead | Predictiv...  15 Feb 2019
# 22                     Data Governance Program Manager  14 Feb 2019
# 23                     Data Governance Program Manager  14 Feb 2019
# 24                                     Program Manager  13 Feb 2019
# 25                                   Big Data Engineer  14 Feb 2019
# 26                              Senior Product Manager  15 Feb 2019
# 27                                   Big Data Engineer  15 Feb 2019
# 28                                          BI Analyst  15 Feb 2019
# 29                        Head of Analytics & Insights  13 Feb 2019
# ..                                                 ...          ...
# 96                  Administration / Enrolment Officer  12 Feb 2019
# 1    b'<p>Our client is a Global leader in their in...  Data Science
# 2    b'We are looking for talented, passionate data...  Data Science
# 3    b'Reporting to the Data Science Manager, our S...  Data Science
# 4    b'<p><strong>Do you want to work in a place wh...  Data Science
# 5    b'Data Scientist required to provide insightfu...  Data Science
# 6    b'This award-winning company on the city fring...  Data Science
# 7    b'This #1 BI Platform company in Australia the...  Data Science
# 8    b'The Data Scientist will collaborate with bus...  Data Science
# 9    b'<p>Our Client is seeking assistance in findi...  Data Science
# 10   b"<p><strong>The Role:</strong></p><p><br/> An...  Data Science
# 11   b'<div><strong>Marketing Analytics Manager</st...  Data Science
# 12   b'We are currently looking for an experienced ...  Data Science
# 13   b'<p>Our client is a leading provider for onli...  Data Science
# 14   b'<strong>APPLY NOW</strong>: Join a newly rec...  Data Science
# 15   b'<div><br/> Just Digital People are working w...  Data Science
# 16   b'<div><br/> Just Digital People are working w...  Data Science
# 17   b'<p><strong>Jnr. S/W Developer(Frontend/Scala...  Data Science
# 18   b"The<strong>\xc2\xa0</strong>Vocus Group Limi...  Data Science
# 19   b"<p>As a Pre-Sales Engineer you have a vital ...  Data Science
# 20   b'<div>We are looking for a passionate Data En...  Data Science
# 21   b'The most important part of any business is t...  Data Science
# 22   b'<p><strong>Data Governance Program Manager</...  Data Science
# 23   b'<p><strong>Data Governance Program Manager</...  Data Science
# 24   b'<p><strong>ADNet Registry Program Manager</s...  Data Science
# 25   b'<ul><li>Exciting large scale big data projec...  Data Science
# 26   b"<p><strong>About us:</strong><br/> <br/> At ...  Data Science
# 27   b'<p> </p><div>Job Description</div><div> </di...  Data Science
# 28   b'<p>We\xe2\x80\x99re JLL. We\xe2\x80\x99re a ...  Data Science
# 29   b'<ul> <li>High growth organisation</li> <li>L...  Data Science
# ..                                                 ...           ...
# 96   b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 97   b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 98   b'<p><strong>Job No.:</strong>\xc2\xa0587166</...  Data Science
# 99   b'<p><strong>Job No.:</strong>\xc2\xa0587166</...  Data Science
# 100  b'<ul>\n<li><strong>Participate in research fo...  Data Science
# 101  b'<ul>\n<li><strong>Participate in research fo...  Data Science
# 102  b'<p>20. This is the number of accounts you wi...  Data Science
# 103  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 104  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 105  b'<p><strong>Reference No.:</strong> 588762</p...  Data Science
# 106  b'<p><strong>Reference No.:</strong> 588762</p...  Data Science
# 107  b'<p><strong>ABOUT US</strong></p> <p>\xc2\xa0...  Data Science
# 108  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 109  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 110  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 111  b'<p><strong>Clinical Project Manager-Melbourn...  Data Science
# 112  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 113  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 114  b'<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 115  b'<p><strong>About the Company:</strong></p> <...  Data Science
# 116  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 117  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 118  b'<strong>Mondel\xc4\x93z International LLC</s...  Data Science
# 119  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 120  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 121  b"<ul>\n<li>Part time role \xe2\x80\x93 3 Days...  Data Science
# 122  b"<ul>\n<li>Part time role \xe2\x80\x93 3 Days...  Data Science
# 123  b"<div>\n<div>\n<div>\n<div>\n<div></div>\n<di...  Data Science
# 124  b'<p><strong>Do you want to work in a place wh...  Data Science
# 125  b'<p><strong>Do you want to work in a place wh...  Data Science
#
# [126 rows x 8 columns]
